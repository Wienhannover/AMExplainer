# %%
# description
# --task: graph classification
# --dataset: ba2(BA-2motifs), mutag
# --num_classes: the number of classes in each dataset
# --epochs: the number of epochs
# --lr: the learning rate
# --alpha/beta: the hyperparameters to tune, which are used to control the terms in loss function(alpha is fixed, only beta changes)
# --gamma: always set to 0, this part belongs to the future work
# --interval: the number of the interval epochs
# --slope_rate: always set to 0, this part belongs to the future work
# --move_rate: the hyperparameter to tune, which is used to control the move distance of the scaling function
# --graph_id: which graph to explain

# %%
# %run main.py --task graph --dataset ba2 --num_classes 2 --epochs 5000 --lr 0.28 --alpha 1 --beta 5 --gamma 0 --interval 1000 --slope_rate 0 --move_rate 1 --graph_id 1
# Out:
# Loading ba2 dataset
# ------------------------------------ 1
# ------------------------------------ 1.0 5.0 0.0
# --------------slope of sigmoid------ 1
# --------------move distance---------- 0
# tensor(3.0993, grad_fn=<SumBackward0>) tensor(0.0525, grad_fn=<SumBackward0>) tensor(5.6960, grad_fn=<SumBackward0>)
# 3.3615357875823975
# ------------------------------------ 2
# ------------------------------------ 1.0 5.0 0.0
# --------------slope of sigmoid------ 1
# --------------move distance---------- 0
# tensor(0.9933, grad_fn=<SumBackward0>) tensor(0.0387, grad_fn=<SumBackward0>) tensor(3.0916, grad_fn=<SumBackward0>)
# 1.1870918273925781
# ------------------------------------ 3
# ------------------------------------ 1.0 5.0 0.0
# --------------slope of sigmoid------ 1
# --------------move distance---------- 0
# tensor(1.0001, grad_fn=<SumBackward0>) tensor(0.0044, grad_fn=<SumBackward0>) tensor(3.3017, grad_fn=<SumBackward0>)
# 1.0222431421279907
# ...
