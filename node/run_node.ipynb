# %%
# description
# --task: node classification
# --dataset: syn1(BA-shapes) syn2(BA-Community) syn3(tree-cycles) syn4(tree-grid)
# --num_classes: the number of classes in each dataset
# --epochs: the number of epochs
# --lr: the learning rate
# --alpha/beta: the hyperparameters to tune, which are used to control the terms in loss function(alpha is set to 1, only beta changes)
# --gamma: always set to 0, this part belongs to the future work
# --interval: the number of the interval epochs
# --slope_rate: always set to 0, this part belongs to the future work
# --move_rate: the hyperparameter to tune, which is used to control the move distance of the scaling function
# --node_id: which node to explain

# %%
# %run main.py --task node --dataset syn3 --num_classes 2 --epochs 5000 --lr 0.28 --alpha 10 --beta 1 --gamma 0 --interval 1000 --slope_rate 0 --move_rate 3 --node_id 511
# Out:
# Loading syn3 dataset
# ------------------------------------ 1
# ------------------------------------ 10.0 1.0 0.0
# --------------slope of sigmoid------ 1
# --------------move distance---------- 0
# tensor(0.1319, grad_fn=<SumBackward0>) tensor(0.0125, grad_fn=<SumBackward0>) tensor(0.0774, grad_fn=<SumBackward0>)
# 1.3314844369888306
# ------------------------------------ 2
# ------------------------------------ 10.0 1.0 0.0
# --------------slope of sigmoid------ 1
# --------------move distance---------- 0
# tensor(0.0217, grad_fn=<SumBackward0>) tensor(0.0357, grad_fn=<SumBackward0>) tensor(0.0199, grad_fn=<SumBackward0>)
# 0.252971351146698
# ------------------------------------ 3
# ------------------------------------ 10.0 1.0 0.0
# --------------slope of sigmoid------ 1
# --------------move distance---------- 0
# tensor(0.0003, grad_fn=<SumBackward0>) tensor(0.0428, grad_fn=<SumBackward0>) tensor(0.0104, grad_fn=<SumBackward0>)
# 0.04605482146143913
# ...
